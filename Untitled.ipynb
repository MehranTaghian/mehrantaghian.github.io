# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def create_wordcloud(text):
    # Create WordCloud object
#     wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text)
    wordcloud = WordCloud(width=1500, height=400, background_color='white', colormap='cividis', max_words=50).generate(text)

    # Display the generated word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    wordcloud.to_file("docs/public/skills.jpg")
    plt.show()

# %%
import yaml
yaml_file_path = 'skills.yml'

# Open the YAML file and load its content into a Python dictionary
with open(yaml_file_path, 'r') as file:
    data = yaml.safe_load(file)

data
# Out:
# {'MachineLearning': 5,
#  'ReinforcementLearning': 5,
#  'Python': 5,
#  'DeepNeuralNets': 4,
#  'Pytorch': 4,
#  'Tensorflow': 3,
#  'DataAnalysis': 4,
#  'Pandas': 3,
#  'Matplotlib': 3,
#  'ScikitLearn': 3,
#  'SciPy': 2,
#  'Robotics': 4,
#  'LargeLangugeModels': 4,
#  'Java': 3,
#  'C': 3,
#  'CUDA': 2,
#  'OpenMP': 2}

# %%
text = ''
for k, v in data.items():
    text += ' ' * v  + k + ' ' * v

# %%
create_wordcloud(text)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Your skills and their respective emphasis
skills_emphasis = {
    'Python': 5,
    'Machine Learning': 4,
    'Data Analysis': 3,
    'JavaScript': 2,
    'Web Development': 3,
    'Communication': 4,
    'Problem Solving': 5,
    'Teamwork': 3,
}

# Generate a string based on skill emphasis
text = ' '.join([skill + ' ' * emphasis for skill, emphasis in skills_emphasis.items()])

# Generate a word cloud with different emphasis
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
